# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
import seaborn as sns

# %%
pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
pip install numpy
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/61.0 kB 330.3 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 651.3 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#     --------------------------------------- 0.2/15.5 MB 7.6 MB/s eta 0:00:03
#    - -------------------------------------- 0.6/15.5 MB 9.7 MB/s eta 0:00:02
#    -- ------------------------------------- 1.0/15.5 MB 9.3 MB/s eta 0:00:02
#    --- ------------------------------------ 1.5/15.5 MB 9.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 2.0/15.5 MB 9.0 MB/s eta 0:00:02
#    ------ --------------------------------- 2.5/15.5 MB 9.5 MB/s eta 0:00:02
#    ------- -------------------------------- 2.9/15.5 MB 9.4 MB/s eta 0:00:02
#    -------- ------------------------------- 3.4/15.5 MB 9.7 MB/s eta 0:00:02
# ...

# %%
pip install seaborn
# Out:
# ...
#      ---------------------------------------- 0.0/162.3 kB ? eta -:--:--
#      ------- ------------------------------- 30.7/162.3 kB 1.3 MB/s eta 0:00:01
#      ---------------------------- --------- 122.9/162.3 kB 1.8 MB/s eta 0:00:01
#      -------------------------------------- 162.3/162.3 kB 1.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ------------------------------- -------- 235.5/294.9 kB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 3.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/7.6 MB 1.1 MB/s eta 0:00:07
#     --------------------------------------- 0.1/7.6 MB 1.2 MB/s eta 0:00:07
#    - -------------------------------------- 0.2/7.6 MB 1.4 MB/s eta 0:00:06
# ...

# %%
df = pd.read_csv("indian_movie.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19951 entries, 0 to 19950
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              19951 non-null  object
#  1   overview           18277 non-null  object
#  2   original_language  19951 non-null  object
#  3   release_date       18058 non-null  object
#  4   genres             15632 non-null  object
#  5   popularity         19951 non-null  float64
#  6   vote_average       19951 non-null  float64
#  7   vote_count         19951 non-null  int64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 1.2+ MB

# %%
df.head()
# Out:
#                              title  \
# 0                              RRR
# 1  Rocky Aur Rani Kii Prem Kahaani
# 2                     Looop Lapeta
# 3                         3 Idiots
# 4            Voice of Sathyanathan
#
#                                             overview original_language  \
# 0  A fictional history of two legendary revolutio...            Telugu
# 1  Gym-freak brat Rocky falls in love with Rani, ...             Hindi
# 2  When her boyfriend loses a mobster's cash, Sav...             Hindi
# 3  Rascal. Joker. Dreamer. Genius... You've never...             Hindi
# 4  A man is mistakenly suspected of being a threa...         Malayalam
#
#   release_date                          genres  popularity  vote_average  \
# 0   24-03-2022                   Action, Drama      81.050           7.8
# 1   28-07-2023  Comedy, Drama, Family, Romance      36.450           0.0
# 2   04-02-2022           Action, Comedy, Crime      32.521           6.1
# ...

# %%
df.shape
# Out:
# (19951, 8)

# %%
df.describe().T
# Out:
#                 count      mean        std  min  25%    50%   75%      max
# popularity    19951.0  1.566615   1.847066  0.0  0.6  0.972  1.77    81.05
# vote_average  19951.0  2.955210   3.244479  0.0  0.0  0.000  6.00    10.00
# vote_count    19951.0  6.425843  42.736186  0.0  0.0  0.000  3.00  4186.00

# %%
df.isnull()
# Out:
#        title  overview  original_language  release_date  genres  popularity  \
# 0      False     False              False         False   False       False
# 1      False     False              False         False   False       False
# 2      False     False              False         False   False       False
# 3      False     False              False         False   False       False
# 4      False     False              False         False   False       False
# ...      ...       ...                ...           ...     ...         ...
# 19946  False     False              False         False   False       False
# 19947  False      True              False         False   False       False
# 19948  False      True              False         False   False       False
# 19949  False     False              False         False    True       False
# 19950  False     False              False          True    True       False
#
#        vote_average  vote_count
# ...

# %%
df.isnull().sum()
# Out:
# title                   0
# overview             1674
# original_language       0
# release_date         1893
# genres               4319
# popularity              0
# vote_average            0
# vote_count              0
# dtype: int64

# %%
sns.scatterplot(x='popularity',y='vote_average',data=df)

# %%
sns.scatterplot(x='genres',y='vote_count',data=df,color='orange')

# %%
df.corr(numeric_only = True)
# Out:
#               popularity  vote_average  vote_count
# popularity      1.000000      0.372797    0.519409
# vote_average    0.372797      1.000000    0.169937
# vote_count      0.519409      0.169937    1.000000

# %%
df[(df['popularity']>20.000) & (df['vote_average']>7.0)][['title','popularity','vote_average']]
# Out:
#                           title  popularity  vote_average
# 0                           RRR      81.050           7.8
# 3                      3 Idiots      30.949           8.0
# 5   Dilwale Dulhania Le Jayenge      28.244           8.6
# 6       Bāhubali: The Beginning      27.127           7.5
# 9                           BRO      24.525           9.0
# 11          Chor Nikal Ke Bhaga      23.046           7.2
# 13   Bāhubali 2: The Conclusion      22.520           7.4
# 17                Minnal Murali      20.411           7.2
# 18    Pushpa: The Rise - Part 1      20.350           7.3

# %%
df.isnull()
# Out:
#        title  overview  original_language  release_date  genres  popularity  \
# 0      False     False              False         False   False       False
# 1      False     False              False         False   False       False
# 2      False     False              False         False   False       False
# 3      False     False              False         False   False       False
# 4      False     False              False         False   False       False
# ...      ...       ...                ...           ...     ...         ...
# 19946  False     False              False         False   False       False
# 19947  False      True              False         False   False       False
# 19948  False      True              False         False   False       False
# 19949  False     False              False         False    True       False
# 19950  False     False              False          True    True       False
#
#        vote_average  vote_count
# ...

# %%
new=df

# %%
x=new['popularity']
y=new['vote_average']
plt.title('movie review')
plt.xlabel('movie')
plt.ylabel('popularity')
plt.bar(x,y)

# %%
new['genres'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
plt.plot(new['popularity'],new['vote_average'],color='green')

# %%
plt.scatter(x,y)

# %%
sns.jointplot(x='popularity',y='vote_average',data=df,color='orange');
